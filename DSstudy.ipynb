# %%
이 프로그램은 파이썬으로 자료구조를 공부하기 위한 스터디로 실습을 통해 익히기 위해 만들었다

# %%
print("hello world")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
i = 0
print(i)

# %%
i = input()
print(i+1)
x = int(i)
print(x+1)
s = str(x)
print(s)

# %%
i = int(input())
if(i<10):
    print("low")
else:
    print("hi")

# %%
for i in range(6):
    print(i)

# %%
def func(x, y):
    plus = x+y
    minus = x-y
    return plus, minus

a, b = func(10, 20)
print(a)
print(b)

# %%
s = "absdefg"
print(s[-1])
print(s[1:4])
print(s[3:])
print(s[:2])
print(len(s))
s1 = s + "xyz"
print(s1)

# %%
s = "어떤 별에 사는 꽃을 좋아한다면 밤에 하늘을 쳐다보는 게 즐거울 거야 어느 별이나 다 꽃이 필테니까"
print(s.count("별"))
print(s.find("별"))
print(s.rfind("별"))
print(s.index("별"))
print(s.split())

a = s.split()
print(a[0])

s = "aa,bb,cc,dd"
print(s.split(','))

# %%
#array list
a = [1,2,3,4,5]
a.append("hi")

a.append(0)
a.append(1)
print(a[1:3])
print(a[2:])

# %%
s = [0, 1, 2, 3, 4]
print(s[-1])
s.append(5)
s[1] = "이주석"
del(s[1])
print(s)
print(s.index(0))
a.sort
print(a)
a.reverse
print(a)
a.remove(3)
print(a)
print(a.count(5))

# %%
"""
자료구조의 1차원 배열을 이해하기 위해, 파이썬이 제공하는 배열 기본함수들을 직접 구현하는 프로그램이다.
규칙은 다음과 같다.
1. 사용할 수 있는 기본함수는 append, del, len만 사용한다.
2. 이미 만든 함수를 사용하여 다른 함수를 만들 수 있다.
3. Error 상황 처리는 각자 완벽하게 한다.
4. 할 수 있는 만큼 최적화한다. 단, 가독성을 해치면 안된다.
"""

array = [99, 22, 4, 55, 66, 77, 99]

#Myappend는 기본적인 append만 사용하여 구현할 수 있다
def Myappend(a):
    array.append(a)

#pop은 삭제된 값을 반환하므로, Mypop도 값을 반환하게 설계한다
def Mypop():
    x = array[len(array)-1]
    del(array[len(array)-1])
    return x

#index는 글자의 인덱스를 돌려주는 함수이다.
def Myindex(a):
    for i in range(0,len(array),1):#(0,len(array)),(len(array))로 바꿀 수 있다
        if (array[i] == a):
            return i
    print(a,"is not in list")

#insert는 원하는 위치에 원하는 값을 집어넣는 프로그램이다
def Myinsert(a, b):
    if (b > len(array)):
        print("IndexError")
        return
    array.append(None)
    for i in range(len(array)-1, b - 1, -1):
        array[i] = array[i-1]
    array[b] = a

#swap으로 인덱스에 해당하는 값들을 바꾼다
def Myswap(a, b):
    array[a], array[b] = array[b], array[a]

#remove로 원하는 값을 삭제한다
def Myremove(a):
    for i in range(len(array)):
        if (array[i] == a):
            del(array[i])
            return
    print(a,"is not in list")

#count로 찾고 싶은 값들의 수를 알려준다
def Mycount(a):
    count = 0
    for i in range(len(array)):
        if (array[i] == a):
            count += 1
    return count

#배열의 순서를 뒤집는다
def Myreverse():
    for i in range(len(array)//2):
        Myswap(i, len(array)-1-i)


print(array)
